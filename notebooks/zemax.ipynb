# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
#from rayoptics.optical.opticalmodel import OpticalModel
from rayoptics.gui.appcmds import open_model
from rayoptics.environment import *


# open an OpticalModel from a file
opm = open_model(r"c:\Users\davidek\Downloads\3345-S02.ZMX")

# or create a new OpticalModel
#opm = OpticalModel()
sm = opm['seq_model']
osp = opm['optical_spec']
pm = opm['parax_model']
em = opm['ele_model']
pt = opm['part_tree']
ar = opm['analysis_results']

# %%
sm.list_model()
isdark = False
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=opm, is_dark=isdark).plot()
# Out:
#               c            t        medium     mode   zdr      sd
#   Obj:     0.000000  1.00000e+10       air             1      1.0000
#  Stop:     0.083612      2.26000     N-BK7             1      3.0000
#     2:    -0.083612      10.5234       air             1      3.0000
#   Img:     0.000000      0.00000                       1     0.10495
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
